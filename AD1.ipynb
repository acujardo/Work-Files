# %%
import pandas as pd

#initialize data


data1 = {
    'Make':['Arctic Cat'],
    'Model':['All Model'],
    'Vendor Code':['NACH'],
    'Vendor Name':['NACHMAN INTERNATIONAL CO.LTD'],
    
  
    
    'MPN':['08-112-02'],
    
    'SKU':['KX0811202'],
    
    'Vendor Notes':['OEM#-0605-202,TYPE-TIE ROD 3/8”-24 NF,Right'],
}

list_models=[
    
    


'Bearcat 454 2x4',
'Bearcat 454 4x4',
'Bearcat 2000 LT',
'Bearcat 2000 LT ES',
'Bearcat 2000 XT',
'Bearcat 2000 XT ES',
'Bearcat 2000 XTE',
'Bearcat 3000 LT',
'Bearcat 340',
'Bearcat 440',
'Bearcat 440 I',
'Bearcat 440 II',
'Bearcat 5000 XT',
'Bearcat 5000 XT GS',
'Bearcat 5000 XT Limited',
'Bearcat 550',
'Bearcat 570',
'Bearcat 570 Long Track',
'Bearcat 570 XT',
'Bearcat 570 XTE',
'Bearcat 7000 XT',
'Bearcat 7000 XT GS',
'Bearcat Widetrack',
'Bearcat Widetrack Turbo',
'Bearcat Widetrack Turbo Articulating',
'Bearcat XT',
'Bearcat Z1 XT',
'Bearcat Z1 XT GS',
'Bearcat Z1 XT Limited',
'Cougar',
'El Tigre EXT',
'El Tigre EXT Mountain Cat',
'El Tigre EXT Special',
'EXT 340',
'EXT 399',
'EXT 440',
'EXT 550',
'EXT 580',
'EXT 580 EFI',
'EXT 580 EFI Deluxe',
'EXT 580 Mountain Cat',
'EXT 580 Z',
'EXT 600',
'EXT 600 Tour',
'EXT 600 Triple',
'EXT EFI',
'EXT EFI Mountain Cat',
'EXT Powder Special',
'EXT Special',
'F6 Firecat EFI EXT',
'F7 Firecat EFI EXT',
'F8 EXT',
'Powder Extreme',
'Sabercat 600 EFI EXT',
'Sabercat 700 EFI EXT',
'Z1 Turbo EXT',
'Z1 Turbo EXT Limited',
'Blast M 4000 Special Edition',
'Jag AFS LT 1 Speed',
'Jag AFS LT 2 Speed',
'Jag Special',
'Powder Special 2K',
'Powder Special 500 EFI',
'Powder Special 500 EFI LE',
'Powder Special 600',
'Powder Special 600 EFI',
'Powder Special 600 EFI LE',
'Powder Special 600 LE',
'Powder Special 700',
'Powder Special 700 LE',
'Prowler Special',
'Wildcat Sport',
'Wildcat Sport Limited',
'Wildcat Sport SE',
'Wildcat Sport XT',
'M 8000 David McClure SE',
'Thundercat MC',
'Jag 340 Deluxe',
'Jag 4000 LT',
'Jag 440 Deluxe',
'Jag AFS Deluxe',
'Jag Deluxe',
'Cougar Mountain Cat',
'Jag Mountain Cat',
'Lynx Mountain Cat',
'M 8000 Mountain Cat 153',
'M 8000 Mountain Cat 162',
'M 8000 Mountain Cat Alpha One 146',
'M 8000 Mountain Cat Alpha One 154',
'M 8000 Mountain Cat Alpha One 154 2.6in.',
'M 8000 Mountain Cat Alpha One 165',
'M 8000 Mountain Cat Alpha One ATAC 146',
'M 8000 Mountain Cat Alpha One ATAC 154',
'M 8000 Mountain Cat Alpha One ATAC 154 2.6in.',
'M 8000 Mountain Cat Alpha One ATAC 165',
'M 8000 Mountain Cat Alpha One ATAC ES 146',
'M 8000 Mountain Cat Alpha One ATAC ES 154',
'M 8000 Mountain Cat Alpha One ATAC ES 154 2.6in.',
'M 8000 Mountain Cat Alpha One ATAC ES 165',
'M 8000 Mountain Cat Alpha One ES 146',
'M 8000 Mountain Cat Alpha One ES 154',
'M 8000 Mountain Cat Alpha One ES 154 2.6in.',
'M 8000 Mountain Cat Alpha One ES 165',
'M 8000 Mountain Cat ES 153',
'M 8000 Mountain Cat ES 162',
'Mountain Cat 1000',
'Mountain Cat 500',
'Mountain Cat 500 EFI',
'Mountain Cat 570',
'Mountain Cat 600 EFI',
'Mountain Cat 600 EFI 136',
'Mountain Cat 600 EFI 144',
'Mountain Cat 600 EFI LE',
'Mountain Cat 600 VEV',
'Mountain Cat 800',
'Mountain Cat 800 EFI',
'Mountain Cat 800 EFI 144',
'Mountain Cat 800 EFI 151',
'Mountain Cat 800 EFI 159',
'Mountain Cat 800 EFI LE 144',
'Mountain Cat 800 EFI LE 151',
'Mountain Cat 800 LE',
'Mountain Cat 800 LE 144',
'Mountain Cat 800 LE 151',
'Mountain Cat 900 144',
'Mountain Cat 900 151',
'Mountain Cat 900 159',
'Mountain Cat 900 1M',
'Mountain Cat 900 Early Build',
'Mountain Cat 900 EFI 151',
'Mountain Cat 900 EFI 159',
'Panther Mountain Cat',
'Prowler Mountain Cat',
'Thundercat Mountain Cat',
'Wildcat EFI Mountain Cat',
'Wildcat Mountain Cat',
'Wildcat Mountain Cat EFI',
'Pantera',
'Panther',
'Panther 340',
'Panther 370',
'Panther 370 R',
'Panther 399',
'Panther 4000',
'Panther 440',
'Panther 440 ESR',
'Panther 500',
'Panther 5000',
'Panther 550',
'Panther 570',
'Panther 570 ESR',
'Panther 570 R',
'Panther 660 Touring',
'Panther 660 Trail',
'Panther Deluxe',
'Panther LC',
'Panther West',
'Prowler',
'Prowler 2-Up',
'Prowler 1000 XT',
'Prowler 500',
'Prowler 550',
'Prowler 650 4x4 Auto',
'Prowler 650 H1',
'Prowler 700 XT',
'Prowler HDX 500',
'Prowler HDX 500 Limited',
'Prowler HDX 500 XT',
'Prowler HDX 700',
'Prowler HDX 700 Limited',
'Prowler HDX 700 XT',
'Prowler HDX 700i',
'Prowler Pro',
'Prowler Pro Crew',
'Prowler Pro Crew EPS',
'Prowler Pro Crew LTD',
'Prowler Pro Crew Ranch Edition',
'Prowler Pro Crew XT',
'Prowler Pro EPS',
'Prowler Pro LTD',
'Prowler Pro Ranch Edition',
'Prowler Pro XT',
'Prowler XT 1000',
'Prowler XT 550',
'Prowler XT 550i',
'Prowler XT 650 4x4 Auto',
'Prowler XT 650 4x4 Auto M4',
'Prowler XT 650 H1',
'Prowler XT 700',
'Prowler XTX 700',
'Prowler XTX 700 H1 EFI',
'Prowler XTX 700 LE',
'Prowler XTX 700i',
'Prowler XTZ 1000',
'Prowler XTZ 1000 Baja',
'Prowler XTZ 1000 H2 EFI',
'Prowler XTZ 1000i',
'Puma',
'Puma 2-Up',
'Puma 340',
'Puma 340T',
'Puma 399',
'Puma 440',
'Puma Deluxe',
'Triple Touring',
'Wildcat',
'Wildcat 650',
'Wildcat EFI',
'Wildcat Touring',
'Wildcat 1000',
'Wildcat 1000 LTD',
'Wildcat 4 1000',
'Wildcat 4 Limited',
'Wildcat 4X',
'Wildcat 4X Limited',
'Wildcat Trail',
'Wildcat Trail Limited',
'Wildcat Trail LTD',
'Wildcat Trail SE',
'Wildcat Trail XT',
'Wildcat X',
'Wildcat X 1000',
'Wildcat X Limited',
'Wildcat X SE',
'Wildcat XX',
'Wildcat XX Black Hills Edition',
'Wildcat XX LTD',
'Wildcat XX SE',
'Z 370',
'Z 370 ES',
'Z 370 ESR',
'Z 370 LX',
'Z 440',
'Z 440 ES',
'Z 440 ESR',
'Z 440 LX',
'Z 440 Sno Pro',
'ZL 440',
'ZL 500',
'ZL 500 EFI',
'ZL 500 EFI ESR',
'ZL 550',
'ZL 550 ESR',
'ZL 580 EFI ESR',
'ZL 600',
'ZL 600 EFI',
'ZL 600 EFI ESR',
'ZL 600 EFI SS',
'ZL 600 EFI SS ESR',
'ZL 700',
'ZL 800 EFI ESR',
'ZL 800 EFI SS',
'ZL 800 ESR',
'Blast ZR 4000',
'ZR 120',
'ZR 200',
'ZR 200 ES',
'ZR 2K',
'ZR 3000',
'ZR 3000 LXR',
'ZR 400',
'ZR 4000 LXR',
'ZR 4000 RR',
'ZR 4000 Sno Pro',
'ZR 440',
'ZR 440 Sno Pro',
'ZR 500',
'ZR 500 EFI',
'ZR 500 EFI ESR',
'ZR 500 EFI LE',
'ZR 500 LE',
'ZR 5000 LXR',
'ZR 580',
'ZR 580 EFI',
'ZR 580 EFI ETT',
'ZR 600',
'ZR 600 ATAC ES 129',
'ZR 600 ATAC ES 137',
'ZR 600 Blair Morgan',
'ZR 600 EFI',
'ZR 600 EFI LE',
'ZR 600 EFI LE Reverse',
'ZR 600 EFI LE XC',
'ZR 600 ES 129',
'ZR 600 ES 137',
'ZR 600 LE',
'ZR 600 R-XC',
'ZR 600 R-XC ES',
'ZR 600 VEV',
'ZR 6000',
'ZR 6000 El Tigre',
'ZR 6000 El Tigre ES',
'ZR 6000 El Tigre ES 129',
'ZR 6000 El Tigre ES 137',
'ZR 6000 ES 129',
'ZR 6000 ES 137',
'ZR 6000 Limited 129',
'ZR 6000 Limited 137',
'ZR 6000 Limited ES 129',
'ZR 6000 Limited ES 129 iACT',
'ZR 6000 Limited ES 137',
'ZR 6000 Limited ES 137 iACT',
'ZR 6000 Limited ES ATAC 137',
'ZR 6000 LXR 129',
'ZR 6000 LXR 137',
'ZR 6000 LXR ES 129',
'ZR 6000 LXR ES 137',
'ZR 6000 R-XC',
'ZR 6000 R-XC ES',
'ZR 6000 R XC',
'ZR 6000 R XC 129',
'ZR 6000 RR',
'ZR 6000 RR ES 129',
'ZR 6000 RR ES 137',
'ZR 6000 RS',
'ZR 6000 Sno Pro 129',
'ZR 6000 Sno Pro 137',
'ZR 6000 Sno Pro ES 129',
'ZR 6000 Sno Pro ES 137',
'ZR 6000 Tucker Hibbert RR',
'ZR 700',
'ZR 700 LE',
'ZR 700 LE Reverse',
'ZR 7000',
'ZR 7000 129',
'ZR 7000 137',
'ZR 7000 El Tigre',
'ZR 7000 Limited 129',
'ZR 7000 Limited 137',
'ZR 7000 Limited 137 iACT',
'ZR 7000 LXR 129',
'ZR 7000 LXR 137',
'ZR 7000 RR',
'ZR 7000 Sno Pro 129',
'ZR 7000 Sno Pro 137',
'ZR 800',
'ZR 800 EFI',
'ZR 800 EFI Sno Pro',
'ZR 800 LE',
'ZR 8000',
'ZR 8000 ATAC',
'ZR 8000 El Tigre',
'ZR 8000 El Tigre ES 129',
'ZR 8000 El Tigre ES 137',
'ZR 8000 ES 129',
'ZR 8000 ES 137',
'ZR 8000 Limited 129',
'ZR 8000 Limited 137',
'ZR 8000 Limited ES 129',
'ZR 8000 Limited ES 129 iACT',
'ZR 8000 Limited ES 137',
'ZR 8000 Limited ES 137 iACT',
'ZR 8000 Limited ES ATAC 137',
'ZR 8000 LXR 129',
'ZR 8000 LXR 137',
'ZR 8000 LXR ES 129',
'ZR 8000 LXR ES 137',
'ZR 8000 RR',
'ZR 8000 RR ES 129',
'ZR 8000 RR ES 137',
'ZR 8000 Sno Pro 129',
'ZR 8000 Sno Pro 137',
'ZR 8000 Sno Pro ES 129',
'ZR 8000 Sno Pro ES 129 Early Build',
'ZR 8000 Sno Pro ES 137',
'ZR 8000 Sno Pro ES 137 Early Build',
'ZR 900',
'ZR 900 Early Build',
'ZR 900 EFI',
'ZR 900 EFI Sno Pro',
'ZR 900 Sno Pro',
'ZR 9000 El Tigre',
'ZR 9000 Limited',
'ZR 9000 Limited 129',
'ZR 9000 Limited 137',
'ZR 9000 Limited iACT',
'ZR 9000 LXR',
'ZR 9000 RR',
'ZR 9000 RR 129',
'ZR 9000 RR 137',
'ZR 9000 Sno Pro 129',
'ZR 9000 Sno Pro 137',
'ZR 9000 Thundercat',
'ZR 9000 Thundercat EPS',
'ZR 9000 Thundercat ATAC',
'ZR 9000 Thundercat EPS ATAC',
'ZR 9000 Thundercat iACT',
'ZRT 600',
'ZRT 600 LE',
'ZRT 800',
'ZRT 800 LE'









    
]

years=list(range(1993,2007))

def generate_df(model,data,year):
    data_copy=data.copy()
    data_copy['Model']=model
    data_copy['Year']=year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1=pd.concat([generate_df(model,data1,year)for model in list_models], ignore_index=True)
    dfs.append(df1)  
                   
final_df=pd.concat(dfs, ignore_index=True)
                   
final_df
# Out:
#             Make                    Model Vendor Code  \
# 0     Arctic Cat          Bearcat 454 2x4        NACH
# 1     Arctic Cat          Bearcat 454 4x4        NACH
# 2     Arctic Cat          Bearcat 2000 LT        NACH
# 3     Arctic Cat       Bearcat 2000 LT ES        NACH
# 4     Arctic Cat          Bearcat 2000 XT        NACH
# ...          ...                      ...         ...
# 5469  Arctic Cat  ZR 9000 Thundercat iACT        NACH
# 5470  Arctic Cat                  ZRT 600        NACH
# 5471  Arctic Cat               ZRT 600 LE        NACH
# 5472  Arctic Cat                  ZRT 800        NACH
# 5473  Arctic Cat               ZRT 800 LE        NACH
#
#                        Vendor Name        MPN        SKU  \
# 0     NACHMAN INTERNATIONAL CO.LTD  08-112-02  KX0811202
# 1     NACHMAN INTERNATIONAL CO.LTD  08-112-02  KX0811202
# 2     NACHMAN INTERNATIONAL CO.LTD  08-112-02  KX0811202
# 3     NACHMAN INTERNATIONAL CO.LTD  08-112-02  KX0811202
# ...

# %%
file_path=r"C:\Users\AD\Desktop\Output\Nachman2023\Section 08\Tie Rod Ends & Caps\08-112-02-1.csv"
final_df.to_csv(file_path,index=False)
